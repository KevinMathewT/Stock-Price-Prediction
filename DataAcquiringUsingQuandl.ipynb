# %%
import quandl
import datetime

# %%
quandl.ApiConfig.api_key = 'pqGuMyr3fy1tdNc39yhU'
 
query_list = ['WIKI' + '/' + 'AAPL' + '.' + str(k) for k in range(1, 13)]
 
start_date = datetime.date(*(2000, 1, 1))
end_date = None
 
if end_date:
    end_date = datetime.date(None)
else:
    end_date = datetime.date.today()
 
apple_data = quandl.get(query_list, 
            returns='pandas', 
            start_date=start_date,
            end_date=end_date,
            collapse='daily',
            order='asc'
            )

# %%
(apple_data.head())
# Out:
#             WIKI/AAPL - Open  WIKI/AAPL - High  WIKI/AAPL - Low  \
# Date
# 2000-01-03            104.87            112.50           101.69
# 2000-01-04            108.25            110.62           101.19
# 2000-01-05            103.75            110.56           103.00
# 2000-01-06            106.12            107.00            95.00
# 2000-01-07             96.50            101.00            95.50
#
#             WIKI/AAPL - Close  WIKI/AAPL - Volume  WIKI/AAPL - Ex-Dividend  \
# Date
# 2000-01-03             111.94           4783900.0                      0.0
# 2000-01-04             102.50           4574800.0                      0.0
# 2000-01-05             104.00           6949300.0                      0.0
# 2000-01-06              95.00           6856900.0                      0.0
# 2000-01-07              99.50           4113700.0                      0.0
#
#             WIKI/AAPL - Split Ratio  WIKI/AAPL - Adj. Open  \
# Date
# ...

# %%
(apple_data.tail())
# Out:
#             WIKI/AAPL - Open  WIKI/AAPL - High  WIKI/AAPL - Low  \
# Date
# 2018-03-21            175.04            175.09           171.26
# 2018-03-22            170.00            172.68           168.60
# 2018-03-23            168.39            169.92           164.94
# 2018-03-26            168.07            173.10           166.44
# 2018-03-27            173.68            175.15           166.92
#
#             WIKI/AAPL - Close  WIKI/AAPL - Volume  WIKI/AAPL - Ex-Dividend  \
# Date
# 2018-03-21            171.270          35247358.0                      0.0
# 2018-03-22            168.845          41051076.0                      0.0
# 2018-03-23            164.940          40248954.0                      0.0
# 2018-03-26            172.770          36272617.0                      0.0
# 2018-03-27            168.340          38962839.0                      0.0
#
#             WIKI/AAPL - Split Ratio  WIKI/AAPL - Adj. Open  \
# Date
# ...

# %%
apple_data.shape
# Out:
# (4585, 12)

# %%
apple_data.to_csv('AppleData.csv')
